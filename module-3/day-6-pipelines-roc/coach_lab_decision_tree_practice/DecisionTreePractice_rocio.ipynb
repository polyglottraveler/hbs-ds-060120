# %% [markdown]
# # Decision Tree Practice

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score, plot_roc_curve
from sklearn import tree

# %%
# Grabbing our data, then exploring it a bit
# Data source: https://www.kaggle.com/ronitf/heart-disease-uci
df = pd.read_csv("heart.csv")

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
X = df.drop(columns = 'target')
y = df.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 7, stratify = y)

# stratify

# %%
y_train.value_counts(normalize = True)
# Out:
# 1    0.545455
# 0    0.454545
# Name: target, dtype: float64

# %%
y_test.value_counts(normalize = True)
# Out:
# 1    0.540984
# 0    0.459016
# Name: target, dtype: float64

# %%
X_train.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 170   56    1   2       130   256    1        0      142      1      0.6
# 124   39    0   2        94   199    0        1      179      0      0.0
# 134   41    0   1       126   306    0        1      163      0      0.0
# 28    65    0   2       140   417    1        0      157      0      0.8
# 208   49    1   2       120   188    0        1      139      0      2.0
#
#      slope  ca  thal
# 170      1   1     1
# 124      2   0     2
# 134      2   0     2
# 28       2   1     2
# 208      1   3     3

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 170 to 11
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       242 non-null    int64
#  1   sex       242 non-null    int64
#  2   cp        242 non-null    int64
#  3   trestbps  242 non-null    int64
#  4   chol      242 non-null    int64
#  5   fbs       242 non-null    int64
#  6   restecg   242 non-null    int64
#  7   thalach   242 non-null    int64
#  8   exang     242 non-null    int64
#  9   oldpeak   242 non-null    float64
#  10  slope     242 non-null    int64
#  11  ca        242 non-null    int64
#  12  thal      242 non-null    int64
# dtypes: float64(1), int64(12)
# memory usage: 26.5 KB

# %%
for col in X_train.columns:
    print(X_train[col].value_counts())
# Out:
# 58    18
# 54    15
# 57    14
# 52    11
# 44    10
# 59     9
# 51     9
# 56     9
# 43     8
# 63     8
# 62     8
# 60     8
# 64     7
# 65     7
# 53     7
# 42     7
# 66     6
# 45     6
# 41     6
# 67     6
# 61     6
# 49     5
# 46     5
# 47     5
# 48     4
# 39     4
# 55     4
# 50     3
# 71     3
# 38     3
# 69     3
# 68     3
# 40     3
# 35     3
# 37     2
# 34     2
# 77     1
# 76     1
# 70     1
# 74     1
# 29     1
# Name: age, dtype: int64
# 1    166
# 0     76
# Name: sex, dtype: int64
# 0    112
# 2     76
# 1     34
# 3     20
# Name: cp, dtype: int64
# 130    28
# 120    28
# 140    25
# 110    15
# 150    14
# 138    11
# 128    10
# 112     9
# 125     8
# 132     7
# 160     7
# 118     7
# 124     6
# 108     6
# 134     5
# 152     5
# 100     4
# 145     3
# 126     3
# 170     3
# 105     3
# 136     3
# 180     3
# 135     3
# 115     2
# 94      2
# 142     2
# 178     2
# 146     2
# 129     1
# 114     1
# 102     1
# 174     1
# 172     1
# 165     1
# 164     1
# 117     1
# 156     1
# 192     1
# 155     1
# 148     1
# 122     1
# 123     1
# 144     1
# 200     1
# Name: trestbps, dtype: int64
# 234    6
# 204    6
# 197    5
# 269    4
# 226    4
#       ..
# 311    1
# 210    1
# 242    1
# 306    1
# 232    1
# Name: chol, Length: 134, dtype: int64
# 0    200
# 1     42
# Name: fbs, dtype: int64
# 1    130
# 0    108
# 2      4
# Name: restecg, dtype: int64
# 162    9
# 173    8
# 152    7
# 163    7
# 144    7
#       ..
# 195    1
# 137    1
# 134    1
# 129    1
# 71     1
# Name: thalach, Length: 87, dtype: int64
# 0    160
# 1     82
# Name: exang, dtype: int64
# 0.0    81
# 1.2    13
# 0.8    12
# 0.6    11
# 1.0    11
# 1.6    10
# 1.4    10
# 0.2     8
# 1.8     8
# 2.0     7
# 0.4     7
# 0.1     7
# 2.8     5
# 0.5     5
# 1.9     4
# 3.0     4
# 3.6     4
# 1.5     3
# 2.2     3
# 2.6     3
# 3.4     3
# 2.5     2
# 1.1     2
# 0.3     2
# 4.2     2
# 0.9     2
# 2.3     2
# 4.0     2
# 4.4     1
# 6.2     1
# 2.1     1
# 0.7     1
# 2.4     1
# 3.5     1
# 3.1     1
# 3.2     1
# 3.8     1
# Name: oldpeak, dtype: int64
# 2    119
# 1    107
# 0     16
# Name: slope, dtype: int64
# 0    134
# 1     54
# 2     32
# 3     17
# 4      5
# Name: ca, dtype: int64
# 2    130
# 3     93
# 1     17
# 0      2
# Name: thal, dtype: int64

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Logistic Regression
#
# ### Preprocessing
#
# What kind of preprocessing steps are there?
# - Imputing
# - Scaling
# - Encoding

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline

# %% [markdown]
# ### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
# Lets set up a Logistic Regression Pipeline

encoder = OneHotEncoder(drop='first')
catvar = ['restecg','slope','ca','thal']
catvarid = [X_train.columns.tolist().index(col) for col in catvar]

catvarid

pipe_lr = make_pipeline(SimpleImputer(),
                       ColumnTransformer([('encoder', encoder, catvarid)],
                                         remainder = 'passthrough', 
                                         sparse_threshold = 0),
                                         StandardScaler(),
                                         LogisticRegression())

pipe_lr.steps
# Out:
# [('simpleimputer', SimpleImputer()),
#  ('columntransformer',
#   ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                     transformers=[('encoder', OneHotEncoder(drop='first'),
#                                    [6, 10, 11, 12])])),
#  ('standardscaler', StandardScaler()),
#  ('logisticregression', LogisticRegression())]

# %%
# Lets fit the LogReg on our training and calculate our roc_auc_scores

pipe_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('columntransformer',
#                  ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                                    transformers=[('encoder',
#                                                   OneHotEncoder(drop='first'),
#                                                   [6, 10, 11, 12])])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
train_pred = pipe_lr.predict_proba(X_train)
test_pred = pipe_lr.predict_proba(X_test)

# %%
train_score = roc_auc_score(y_train, train_pred[:,1])
test_score = roc_auc_score(y_test, test_pred[:,1])

# %%
print(f'Train ROC-AUC score:{train_score}')
print(f'Test ROC-AUC score:{test_score}')
# Out:
# Train ROC-AUC score:0.9495179063360881
# Test ROC-AUC score:0.8831168831168832

# %% [markdown]
# How'd we do?

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# #### let's do a basic decision tree with just the default values

# %%
from sklearn.tree import DecisionTreeClassifier
# Fit the model and lets see the tree

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(30,30))
tree.plot_tree(dt)
# Out:
# [Text(1041.01875, 1556.6727272727271, 'X[2] <= 0.5\ngini = 0.496\nsamples = 242\nvalue = [110, 132]'),
#  Text(659.1375, 1408.418181818182, 'X[11] <= 0.5\ngini = 0.366\nsamples = 112\nvalue = [85, 27]'),
#  Text(397.575, 1260.1636363636362, 'X[8] <= 0.5\ngini = 0.5\nsamples = 49\nvalue = [24, 25]'),
#  Text(209.25, 1111.909090909091, 'X[12] <= 2.5\ngini = 0.365\nsamples = 25\nvalue = [6, 19]'),
#  Text(125.55000000000001, 963.6545454545454, 'X[4] <= 316.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(83.7, 815.4, 'X[7] <= 96.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(41.85, 667.1454545454545, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(125.55000000000001, 667.1454545454545, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(167.4, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(292.95, 963.6545454545454, 'X[0] <= 53.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(251.10000000000002, 815.4, 'X[4] <= 215.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(209.25, 667.1454545454545, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(292.95, 667.1454545454545, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(334.8, 815.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(585.9, 1111.909090909091, 'X[9] <= 0.1\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(460.35, 963.6545454545454, 'X[3] <= 129.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(418.5, 815.4, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(502.20000000000005, 815.4, 'X[3] <= 158.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(460.35, 667.1454545454545, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(544.0500000000001, 667.1454545454545, 'X[7] <= 148.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(502.20000000000005, 518.890909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(585.9, 518.890909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(711.45, 963.6545454545454, 'X[3] <= 115.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(669.6, 815.4, 'X[0] <= 48.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(627.75, 667.1454545454545, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(711.45, 667.1454545454545, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(753.3000000000001, 815.4, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(920.7, 1260.1636363636362, 'X[3] <= 109.0\ngini = 0.061\nsamples = 63\nvalue = [61, 2]'),
#  Text(837.0, 1111.909090909091, 'X[11] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(795.15, 963.6545454545454, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(878.85, 963.6545454545454, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1004.4000000000001, 1111.909090909091, 'X[7] <= 105.5\ngini = 0.033\nsamples = 59\nvalue = [58, 1]'),
#  Text(962.5500000000001, 963.6545454545454, 'X[9] <= 0.6\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(920.7, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1004.4000000000001, 815.4, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1046.25, 963.6545454545454, 'gini = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(1422.9, 1408.418181818182, 'X[9] <= 1.95\ngini = 0.311\nsamples = 130\nvalue = [25, 105]'),
#  Text(1339.2, 1260.1636363636362, 'X[3] <= 176.0\ngini = 0.236\nsamples = 117\nvalue = [16, 101]'),
#  Text(1297.3500000000001, 1111.909090909091, 'X[0] <= 55.5\ngini = 0.214\nsamples = 115\nvalue = [14, 101]'),
#  Text(1171.8, 963.6545454545454, 'X[7] <= 135.0\ngini = 0.081\nsamples = 71\nvalue = [3, 68]'),
#  Text(1088.1000000000001, 815.4, 'X[7] <= 125.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(1046.25, 667.1454545454545, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1129.95, 667.1454545454545, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1255.5, 815.4, 'X[3] <= 109.0\ngini = 0.03\nsamples = 66\nvalue = [1, 65]'),
#  Text(1213.65, 667.1454545454545, 'X[7] <= 153.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(1171.8, 518.890909090909, 'X[10] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(1129.95, 370.63636363636374, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1213.65, 370.63636363636374, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1255.5, 518.890909090909, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(1297.3500000000001, 667.1454545454545, 'gini = 0.0\nsamples = 57\nvalue = [0, 57]'),
#  Text(1422.9, 963.6545454545454, 'X[12] <= 1.5\ngini = 0.375\nsamples = 44\nvalue = [11, 33]'),
#  Text(1381.05, 815.4, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1464.75, 815.4, 'X[3] <= 139.0\ngini = 0.337\nsamples = 42\nvalue = [9, 33]'),
#  Text(1381.05, 667.1454545454545, 'X[3] <= 122.0\ngini = 0.455\nsamples = 20\nvalue = [7, 13]'),
#  Text(1339.2, 518.890909090909, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(1422.9, 518.890909090909, 'X[11] <= 2.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(1381.05, 370.63636363636374, 'X[11] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(1339.2, 222.38181818181806, 'X[9] <= 0.15\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(1297.3500000000001, 74.12727272727284, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1381.05, 74.12727272727284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1422.9, 222.38181818181806, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1464.75, 370.63636363636374, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1548.45, 667.1454545454545, 'X[1] <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(1506.6000000000001, 518.890909090909, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(1590.3, 518.890909090909, 'X[4] <= 290.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(1548.45, 370.63636363636374, 'X[0] <= 65.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(1506.6000000000001, 222.38181818181806, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(1590.3, 222.38181818181806, 'X[12] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(1548.45, 74.12727272727284, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1632.15, 74.12727272727284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1632.15, 370.63636363636374, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1381.05, 1111.909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1506.6000000000001, 1260.1636363636362, 'X[10] <= 0.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(1464.75, 1111.909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1548.45, 1111.909090909091, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]')]

# %%
dt.get_depth()
# Out:
# 10

# %%
# Lets calculate the roc_auc_score
train_pred = dt.predict_proba(X_train)
test_pred = dt.predict_proba(X_test)

# %%
train_score = roc_auc_score(y_train, train_pred[:,1])
test_score = roc_auc_score(y_test, test_pred[:,1])

print(f'Train ROC-AUC score:{train_score}')
print(f'Test ROC-AUC score:{test_score}')
# Out:
# Train ROC-AUC score:0.9495179063360881
# Test ROC-AUC score:0.8831168831168832

# %% [markdown]
# #### A simple decision tree with a single split

# %%
# lets set up the Decision Tree with a single split
dt_1 = DecisionTreeClassifier(max_depth =1)
dt_1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
# Visualizing the single-split decision tree
plt.figure(figsize=(10,10))
tree.plot_tree(dt_1)
# Out:
# [Text(279.0, 407.70000000000005, 'X[2] <= 0.5\ngini = 0.496\nsamples = 242\nvalue = [110, 132]'),
#  Text(139.5, 135.89999999999998, 'gini = 0.366\nsamples = 112\nvalue = [85, 27]'),
#  Text(418.5, 135.89999999999998, 'gini = 0.311\nsamples = 130\nvalue = [25, 105]')]

# %%
# Lets calculate the roc_auc_score

train_pred = dt_1.predict_proba(X_train)
test_pred = dt_1.predict_proba(X_test)
train_score = roc_auc_score(y_train, train_pred[:,1])
test_score = roc_auc_score(y_test, test_pred[:,1])

print(f'Train ROC-AUC score:{train_score}')
print(f'Test ROC-AUC score:{test_score}')
# Out:
# Train ROC-AUC score:0.784090909090909
# Test ROC-AUC score:0.6574675324675324

# %% [markdown]
# #### Try something Random!

# %%
# Okay - time to change things!
# Replace None with relevant code
dt_2 = DecisionTreeClassifier(max_depth= 5, criterion='entropy', 
                              min_samples_split=10)

dt_2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)

# %%
# Visualizing the decision tree
plt.figure(figsize=(20,20))
tree.plot_tree(dt_2)
# Out:
# [Text(658.44, 996.6, 'X[2] <= 0.5\nentropy = 0.994\nsamples = 242\nvalue = [110, 132]'),
#  Text(401.76, 815.4000000000001, 'X[11] <= 0.5\nentropy = 0.797\nsamples = 112\nvalue = [85, 27]'),
#  Text(223.2, 634.2, 'X[8] <= 0.5\nentropy = 1.0\nsamples = 49\nvalue = [24, 25]'),
#  Text(89.28, 453.0, 'X[4] <= 215.0\nentropy = 0.795\nsamples = 25\nvalue = [6, 19]'),
#  Text(44.64, 271.79999999999995, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(133.92000000000002, 271.79999999999995, 'X[12] <= 2.5\nentropy = 0.937\nsamples = 17\nvalue = [6, 11]'),
#  Text(89.28, 90.59999999999991, 'entropy = 0.65\nsamples = 12\nvalue = [2, 10]'),
#  Text(178.56, 90.59999999999991, 'entropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(357.12, 453.0, 'X[9] <= 1.55\nentropy = 0.811\nsamples = 24\nvalue = [18, 6]'),
#  Text(312.48, 271.79999999999995, 'X[7] <= 162.0\nentropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(267.84000000000003, 90.59999999999991, 'entropy = 0.946\nsamples = 11\nvalue = [7, 4]'),
#  Text(357.12, 90.59999999999991, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(401.76, 271.79999999999995, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(580.32, 634.2, 'X[9] <= 0.4\nentropy = 0.203\nsamples = 63\nvalue = [61, 2]'),
#  Text(535.6800000000001, 453.0, 'X[7] <= 106.5\nentropy = 0.567\nsamples = 15\nvalue = [13, 2]'),
#  Text(491.04, 271.79999999999995, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(580.32, 271.79999999999995, 'X[3] <= 109.0\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(535.6800000000001, 90.59999999999991, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(624.96, 90.59999999999991, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(624.96, 453.0, 'entropy = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(915.12, 815.4000000000001, 'X[9] <= 1.95\nentropy = 0.706\nsamples = 130\nvalue = [25, 105]'),
#  Text(803.52, 634.2, 'X[0] <= 55.5\nentropy = 0.576\nsamples = 117\nvalue = [16, 101]'),
#  Text(714.24, 453.0, 'X[7] <= 135.0\nentropy = 0.31\nsamples = 72\nvalue = [4, 68]'),
#  Text(669.6, 271.79999999999995, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(758.88, 271.79999999999995, 'X[3] <= 182.0\nentropy = 0.194\nsamples = 67\nvalue = [2, 65]'),
#  Text(714.24, 90.59999999999991, 'entropy = 0.113\nsamples = 66\nvalue = [1, 65]'),
#  Text(803.52, 90.59999999999991, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(892.8, 453.0, 'X[3] <= 122.0\nentropy = 0.837\nsamples = 45\nvalue = [12, 33]'),
#  Text(848.16, 271.79999999999995, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(937.44, 271.79999999999995, 'X[3] <= 139.0\nentropy = 0.918\nsamples = 36\nvalue = [12, 24]'),
#  Text(892.8, 90.59999999999991, 'entropy = 0.918\nsamples = 12\nvalue = [8, 4]'),
#  Text(982.08, 90.59999999999991, 'entropy = 0.65\nsamples = 24\nvalue = [4, 20]'),
#  Text(1026.72, 634.2, 'X[10] <= 0.5\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(982.08, 453.0, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1071.3600000000001, 453.0, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]')]

# %%
# Lets calculate the roc_auc_score
train_preds = dt_2.predict_proba(X_train)
test_preds = dt_2.predict_proba(X_test)

train_score = roc_auc_score(y_train, train_preds[:,1])
test_score = roc_auc_score(y_test, test_preds[:,1])

print(f"Train ROC-AUC: {train_score}")
print(f"Test ROC-AUC: {test_score}")
# Out:
# Train ROC-AUC: 0.9758264462809917
# Test ROC-AUC: 0.737012987012987

# %% [markdown]
# ## [GridSearch](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
#
# Lets start by taking a look at the documentation

# %%
grid_params = {
    'max_depth': [3,4,5,6,7],
    'max_features':['sqrt', 'log2'],
    'class_weight':[None, 'balanced'],
    'criterion':['gini','entropy']
}

grid_search = GridSearchCV(dt, grid_params, cv=4, scoring='roc_auc')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': [None, 'balanced'],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7],
#                          'max_features': ['sqrt', 'log2']},
#              scoring='roc_auc')

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4, max_features='log2')

# %%
dt_grid = grid_search.best_estimator_
dt_grid.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, max_features='log2')

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_grid)
# Out:
# [Text(606.1034482758621, 978.48, 'X[0] <= 54.5\ngini = 0.496\nsamples = 242\nvalue = [110, 132]'),
#  Text(307.86206896551727, 761.0400000000001, 'X[10] <= 1.5\ngini = 0.422\nsamples = 119\nvalue = [36, 83]'),
#  Text(153.93103448275863, 543.6, 'X[2] <= 0.5\ngini = 0.499\nsamples = 46\nvalue = [24, 22]'),
#  Text(76.96551724137932, 326.1600000000001, 'X[7] <= 173.5\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(38.48275862068966, 108.72000000000003, 'gini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(115.44827586206898, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(230.89655172413796, 326.1600000000001, 'X[2] <= 2.5\ngini = 0.287\nsamples = 23\nvalue = [4, 19]'),
#  Text(192.41379310344828, 108.72000000000003, 'gini = 0.188\nsamples = 19\nvalue = [2, 17]'),
#  Text(269.3793103448276, 108.72000000000003, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(461.79310344827593, 543.6, 'X[11] <= 0.5\ngini = 0.275\nsamples = 73\nvalue = [12, 61]'),
#  Text(384.82758620689657, 326.1600000000001, 'X[9] <= 1.55\ngini = 0.177\nsamples = 51\nvalue = [5, 46]'),
#  Text(346.3448275862069, 108.72000000000003, 'gini = 0.15\nsamples = 49\nvalue = [4, 45]'),
#  Text(423.3103448275862, 108.72000000000003, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(538.7586206896552, 326.1600000000001, 'X[2] <= 0.5\ngini = 0.434\nsamples = 22\nvalue = [7, 15]'),
#  Text(500.2758620689656, 108.72000000000003, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(577.2413793103449, 108.72000000000003, 'gini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(904.344827586207, 761.0400000000001, 'X[0] <= 68.5\ngini = 0.479\nsamples = 123\nvalue = [74, 49]'),
#  Text(769.6551724137931, 543.6, 'X[2] <= 0.5\ngini = 0.462\nsamples = 113\nvalue = [72, 41]'),
#  Text(692.6896551724138, 326.1600000000001, 'X[8] <= 0.5\ngini = 0.278\nsamples = 66\nvalue = [55, 11]'),
#  Text(654.2068965517242, 108.72000000000003, 'gini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(731.1724137931035, 108.72000000000003, 'gini = 0.172\nsamples = 42\nvalue = [38, 4]'),
#  Text(846.6206896551724, 326.1600000000001, 'X[3] <= 139.0\ngini = 0.462\nsamples = 47\nvalue = [17, 30]'),
#  Text(808.1379310344828, 108.72000000000003, 'gini = 0.5\nsamples = 24\nvalue = [12, 12]'),
#  Text(885.1034482758621, 108.72000000000003, 'gini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(1039.0344827586207, 543.6, 'X[4] <= 303.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(1000.5517241379312, 326.1600000000001, 'X[11] <= 2.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(962.0689655172415, 108.72000000000003, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(1039.0344827586207, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1077.5172413793105, 326.1600000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %% [markdown]
# # Vizualizing all the models scores

# %%
# Visualizing the ROCs for the models we've done
fig, ax = plt.subplots()
plot_roc_curve(pipe_lr, X_test, y_test, name="Baseline Log Reg", ax=ax)
plot_roc_curve(dt, X_test, y_test, name="Default DT", ax=ax)
plot_roc_curve(dt_1, X_test, y_test, name="DT with Max Depth = 1", ax=ax)
plot_roc_curve(dt_2, X_test, y_test, name="DT with Hyper Parameters", ax=ax)
plot_roc_curve(dt_grid, X_test, y_test, name="DT after Grid Search", ax=ax)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Chance', alpha=.8)
plt.title("Receiver Operating Characteristic Curves\n(Evaluated on Test Set)")
ax.legend()
plt.show()

# %% [markdown]
# What can we learn from this visualization? Which is the best model - and how could you tell without looking at the scores?
#
# - Baseline is still best - from both the visualization (closest to the '1' corner) and from the score
